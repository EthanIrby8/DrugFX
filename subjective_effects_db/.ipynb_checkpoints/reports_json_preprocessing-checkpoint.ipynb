# %%
import pandas as pd
import json

# %%
reports = pd.read_json('reports.json', lines=True)
reports.head()
# Out:
#                                     _id  \
# 0  {'$oid': '5b6283c45c4eef141ec0e53b'}
# 1  {'$oid': '5b650d3a2dc00633237aea4c'}
# 2  {'$oid': '5b66069b887f2c39ddcb378c'}
# 3  {'$oid': '5b672bde76af1e4535063001'}
# 4  {'$oid': '5b67332176af1e4535063006'}
#
#                                              subject  \
# 0  {'name': 'Josie', 'trip_date': '19/03/2018', '...
# 1  {'name': 'Josie', 'trip_date': '09/04/2018', '...
# 2  {'name': 'Josie', 'trip_date': '01/03/2018', '...
# 3  {'name': 'Kaylee', 'trip_date': '19/03/2018', ...
# 4  {'name': 'Josie', 'trip_date': '26/03/2018', '...
#
#                                         tags                         title  \
# 0                 [Josie, Salvia, delirious]            Delirious laughter
# 1                   [4-HO-MET, Unity, josie]           Unity with a friend
# 2     [2C-E, Josie, internal hallucinations]   Hallucinate everything mode
# 3  [internal hallucinations, kaylee, salvia]  Salvia people in a courtyard
# 4                    [DXM, Josie, spiritual]      Psychedelic dissociation
#
#                                           substances  \
# 0  [{'_id': {'$oid': '5b6283c45c4eef141ec0e53c'},...
# 1  [{'_id': {'$oid': '5b650d3a2dc00633237aea4d'},...
# 2  [{'_id': {'$oid': '5b66069b887f2c39ddcb378d'},...
# 3  [{'_id': {'$oid': '5b672bde76af1e4535063002'},...
# 4  [{'_id': {'$oid': '5b67332176af1e4535063008'},...
#
#                                                onset  \
# 0                                                 []
# 1  [{'_id': {'$oid': '5b650d3a2dc00633237aea57'},...
# 2  [{'_id': {'$oid': '5b66069b887f2c39ddcb37a6'},...
# 3  [{'_id': {'$oid': '5b672bde76af1e4535063003'},...
# 4  [{'_id': {'$oid': '5b67332176af1e453506301b'},...
#
#                                                 peak  \
# 0  [{'_id': {'$oid': '5b6634e5ae67013dd4c7ec73'},...
# 1  [{'_id': {'$oid': '5b650d3a2dc00633237aea59'},...
# 2  [{'_id': {'$oid': '5b66069b887f2c39ddcb37a7'},...
# 3  [{'_id': {'$oid': '5b672bde76af1e4535063004'},...
# 4  [{'_id': {'$oid': '5b67332176af1e4535063027'},...
#
#                                               offset  \
# 0  [{'_id': {'$oid': '5b6286d5fb27a214cac41d1a'},...
# 1  [{'_id': {'$oid': '5b650d3a2dc00633237aea5a'},...
# 2  [{'_id': {'$oid': '5b66069b887f2c39ddcb37ac'},...
# 3  [{'_id': {'$oid': '5b672bde76af1e4535063005'},...
# 4  [{'_id': {'$oid': '5b67332176af1e453506302c'},...
#
#                                           conclusion  \
# 0  This trip was incredibly confusing while also ...
# 1  I am incredibly lucky to have experienced this...
# 2  This trip was an absolutely mindblowing experi...
# 3                                                NaN
# 4  Once again DXM has far exceeded my expectation...
#
#                                    sectionVisibility  \
# 0  {'subject': True, 'substances': True, 'onset':...
# 1  {'subject': True, 'substances': True, 'onset':...
# 2  {'subject': True, 'substances': True, 'onset':...
# 3  {'subject': True, 'substances': True, 'onset':...
# 4  {'subject': True, 'substances': True, 'onset':...
#
#                            slug  __v  featured  \
# 0            delirious-laughter   11     False
# 1           unity-with-a-friend    5      True
# 2   hallucinate-everything-mode    5      True
# 3  salvia-people-in-a-courtyard    4     False
# 4      psychedelic-dissociation    3     False
#
#                                      related_effects introduction description
# 0  [{'$oid': '5b81b3edf228e642f0829ce6'}, {'$oid'...          NaN         NaN
# 1  [{'$oid': '5b49a89bea24120b49b24b58'}, {'$oid'...          NaN         NaN
# 2  [{'$oid': '5b7b474439b82210cf57a610'}, {'$oid'...          NaN         NaN
# 3  [{'$oid': '5b565c624227356db808661d'}, {'$oid'...          NaN         NaN
# 4  [{'$oid': '5b75cde36b7b4d388828c645'}, {'$oid'...          NaN         NaN

# %%
reports.columns
# Out:
# Index(['_id', 'substances', 'tags', 'title', 'subject', 'description',
#        'related_effects', 'slug', 'onset', 'peak', 'offset',
#        'sectionVisibility', 'featured', 'introduction', 'conclusion', '_v'],
#       dtype='object')

# %% [markdown]
# # SUBJECT

# %%
subject_df = pd.DataFrame(reports.subject.values.tolist())
subject_df.head()
# Out:
#      name   trip_date age  gender  \
# 0   Josie  19/03/2018  25  female
# 1   Josie  09/04/2018  25  Female
# 2   Josie  01/03/2018  25  Female
# 3  Kaylee  19/03/2018  24  Female
# 4   Josie  26/03/2018  25  Female
#
#                                              setting height    weight  \
# 0  In my flat with my girlfriend who is tripsitti...   5ft9  150 lb's
# 1  An apartment in Seattle with a close internet ...   5ft9    150 lb
# 2  Inside my flat with my girlfriend who is also ...   5ft9   ~150lbs
# 3  Inside my apartment with my girlfriend who was...    6ft   ~150lbs
# 4        In my flat with my gf who is also tripping.   5ft9  ~150 lbs
#
#                                              pdf_url  \
# 0  https://drive.google.com/file/d/1N9VPIEeC3fRBl...
# 1  https://drive.google.com/file/d/1vR0IeMKEkqmdw...
# 2  https://drive.google.com/file/d/1t2ZFzA_Zt0sPu...
# 3  https://drive.google.com/file/d/1N9VPIEeC3fRBl...
# 4  https://drive.google.com/file/d/1Qs67Ox0pTuRGD...
#
#                                    medications
# 0  300 mg spironolactone / 8mg estrodiol daily
# 1  300 mg spironolactone / 8mg estrodiol daily
# 2  300 mg spironolactone / 8mg estrodiol daily
# 3                                          NaN
# 4  300mg spironolactone / 8 mg estrodiol daily

# %% [markdown]
# # SectionVisibility

# %%
sV_df = pd.DataFrame(reports.sectionVisibility.values.tolist())
sV_df.head()
# Out:
#    subject  substances  onset  peak  offset  introduction  description  \
# 0     True        True   True  True    True          True        False
# 1     True        True   True  True    True          True        False
# 2     True        True   True  True    True         False        False
# 3     True        True   True  True    True         False        False
# 4     True        True   True  True    True         False        False
#
#    conclusion  tags  relatedEffects
# 0        True  True            True
# 1        True  True            True
# 2        True  True            True
# 3       False  True            True
# 4        True  True            True

# %% [markdown]
# ## slug column .

# %%
slug_df = pd.DataFrame(reports.slug.values.tolist())
slug_df = slug_df.rename(columns={0: 'SLUG?'})
slug_df.head(10)
# Out:
#                           SLUG?
# 0            delirious-laughter
# 1           unity-with-a-friend
# 2   hallucinate-everything-mode
# 3  salvia-people-in-a-courtyard
# 4      psychedelic-dissociation
# 5        ketamine-case-report-1
# 6            re-discovering-dxm
# 7        unusually-intense-trip
# 8   an-underwhelming-experience
# 9   first-trip-in-over-6-months

# %% [markdown]
# # Title

# %%
title_df = pd.DataFrame(reports.title.values.tolist())
title_df = title_df.rename(columns={0: 'title of report'})
title_df.head(10)
# Out:
#                 title of report
# 0            Delirious laughter
# 1           Unity with a friend
# 2   Hallucinate everything mode
# 3  Salvia people in a courtyard
# 4      Psychedelic dissociation
# 5       Ketamine Case Report #1
# 6            Re-discovering DXM
# 7       Unusually intense trip
# 8   An underwhelming experience
# 9   First trip in over 6 months

# %% [markdown]
# # Substances

# %%
substances_df = pd.DataFrame(reports.substances.values.tolist())[0]
substances_df = pd.DataFrame.from_records(substances_df)
substances_df = substances_df.rename(columns={'dose': 'Dose', 'name': 'Substance Name', 'roa': 'ROA'})
substances_df = substances_df[['Substance Name', 'Dose', 'ROA']]
substances_df.head()
# Out:
#      Substance Name                 Dose     ROA
# 0  Salvia divinorum  30mg of 15x extract  smoked
# 1          4-HO-MET                 60mg    Oral
# 2              2C-E                 25mg    Oral
# 3  Salvia divinorum  30mg of 15x extract  Smoked
# 4               DXM               531 mg    Oral

# %% [markdown]
# # ONSET

# %%
for i, value in enumerate(reports.onset.values.tolist()):
    for info in value:
        for j in list(key):
            if '_id' in info: del info['_id']

# %%
onset_df = pd.DataFrame(reports.onset.values.tolist()[1:])

onset_df = pd.DataFrame.from_records(onset_df)

onset_df = pd.melt(onset_df, id_vars=[0])
onset_df.drop(columns='variable', inplace=True)

onset_df = pd.concat([onset_df[0].apply(pd.Series), onset_df['value'].apply(pd.Series, index=onset_df.columns)], axis=1)

onset_df.drop(columns='value',inplace=True)
onset_df.drop(columns=0,inplace=True)

onset_df.head()
# Out:
#                                     _id      time  \
# 0  {'$oid': '5b650d3a2dc00633237aea57'}  12:30 pm
# 1  {'$oid': '5b66069b887f2c39ddcb37a6'}   1:20 pm
# 2  {'$oid': '5b672bde76af1e4535063003'}   4:43 pm
# 3  {'$oid': '5b67332176af1e453506301b'}   7:35 pm
# 4  {'$oid': '5b6767f1fc7f8252c270845a'}    T+0:00
#
#                                          description
# 0  I consumed 60mg 4-ho-met in a gelcap. This was...
# 1  I took 25mg of 2C-E which I acquired through a...
# 2                                      smokes salvia
# 3                          Ingested the DXM bottles.
# 4                  50mg of racemic ketamine snorted.

# %% [markdown]
# # PEAK

# %%
for i, value in enumerate(reports.peak.values.tolist()):
    for info in value:
        for j in list(key):
            if '_id' in info: del info['_id']

# %%
peak_df = pd.DataFrame(reports.peak.values.tolist()[1:])

peak_df = pd.DataFrame.from_records(peak_df)

peak_df = pd.melt(peak_df, id_vars=[0])
peak_df.drop(columns='variable', inplace=True)

peak_df = pd.concat([peak_df[0].apply(pd.Series), peak_df['value'].apply(pd.Series, index=peak_df.columns)], axis=1)

peak_df.drop(columns='value',inplace=True)
peak_df.drop(columns=0,inplace=True)
peak_df.head()
# Out:
#                                     _id      time  \
# 0  {'$oid': '5b650d3a2dc00633237aea59'}   3:00 pm
# 1  {'$oid': '5b66069b887f2c39ddcb37a7'}   5:58 pm
# 2  {'$oid': '5b672bde76af1e4535063004'}   4:45 pm
# 3  {'$oid': '5b67332176af1e4535063027'}  10:20 pm
# 4  {'$oid': '5b6767f1fc7f8252c270845b'}    T+0:25
#
#                                          description
# 0  At this point, I seem to be peaking. The effec...
# 1  Mother of God. I have seen so much that it is ...
# 2  I was getting a weird half breakthrough. After...
# 3  I vomited three times into a bucket and then s...
# 4  I have reached the peak. It is very mild and I...

# %% [markdown]
# # OFFSET

# %%
for i, value in enumerate(reports.offset.values.tolist()):
    for info in value:
        for j in list(key):
            if '_id' in info: del info['_id']

# %%
offset_df = pd.DataFrame(reports.offset.values.tolist()[1:])

offset_df = pd.DataFrame.from_records(offset_df)

offset_df = pd.melt(offset_df, id_vars=[0])
offset_df.drop(columns='variable', inplace=True)

offset_df = pd.concat([offset_df[0].apply(pd.Series), offset_df['value'].apply(pd.Series, index=offset_df.columns)], axis=1)

offset_df.drop(columns='value',inplace=True)
offset_df.drop(columns=0,inplace=True)
offset_df.head()
# Out:
#                                     _id      time  \
# 0  {'$oid': '5b650d3a2dc00633237aea5a'}   6:00 pm
# 1  {'$oid': '5b66069b887f2c39ddcb37ac'}   6:38 pm
# 2  {'$oid': '5b672bde76af1e4535063005'}   5:11 pm
# 3  {'$oid': '5b67332176af1e453506302c'}  12:29 am
# 4  {'$oid': '5b6767f1fc7f8252c2708464'}    T+0:45
#
#                                          description
# 0  At this point, I had lost the feeling and retu...
# 1  I have come down ever so slightly and am now w...
# 2  I have returned to baseline. There do not appe...
# 3  At this point, I am starting to come down as t...
# 4  I am still tripping moderately hard but I am b...
